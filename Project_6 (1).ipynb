# %%
import os
from datetime import datetime


class JournalManager:
    def __init__(self, filename="journal.txt"):
        self.filename = filename

    def add_entry(self, entry_text):
        try:
            timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            with open(self.filename, "a") as f:
                f.write(f"[{timestamp}]\n{entry_text}\n\n")
            print("Entry added successfully!")
        except PermissionError:
            print("Error: You do not have permission to write to this file.")
        except Exception as e:
            print(f"An unexpected error occurred: {e}")

    def view_entries(self):
        try:
            with open(self.filename, "r") as f:
                content = f.read().strip()
            if not content:
                print("No journal entries found. Start by adding a new entry!")
                return
            print("Your Journal Entries:")
            print("-" * 30)
            print(content)
        except FileNotFoundError:
            print("No journal entries found. Start by adding a new entry!")
        except PermissionError:
            print("Error: You do not have permission to read this file.")
        except Exception as e:
            print(f"An unexpected error occurred: {e}")

    def search_entries(self, keyword):
        try:
            with open(self.filename, "r") as f:
                content = f.read().strip()
            if not content:
                print("No journal entries found. Start by adding a new entry!")
                return
            entries = content.split("\n\n")
            matches = [entry for entry in entries if keyword.lower() in entry.lower()]
            if matches:
                print("Matching Entries:")
                print("-" * 30)
                print("\n\n".join(matches))
            else:
                print(f"No entries were found for the keyword: {keyword}.")
        except FileNotFoundError:
            print("Error: The journal file does not exist. Please add a new entry first.")
        except PermissionError:
            print("Error: You do not have permission to read this file.")
        except Exception as e:
            print(f"An unexpected error occurred: {e}")

    def delete_entries(self):
        try:
            if not os.path.exists(self.filename):
                print("No journal entries to delete.")
                return
            confirmation = input("Are you sure you want to delete all entries? (yes/no): ").strip().lower()
            if confirmation == "yes":
                os.remove(self.filename)
                print("All journal entries have been deleted.")
            else:
                print("Deletion cancelled.")
        except PermissionError:
            print("Error: You do not have permission to delete this file.")
        except Exception as e:
            print(f"An unexpected error occurred: {e}")


def display_menu():
    print("\nWelcome to Personal Journal Manager!")
    print("Please select an option:\n")
    print("1. Add a New Entry")
    print("2. View All Entries")
    print("3. Search for an Entry")
    print("4. Delete All Entries")
    print("5. Exit")


def main():
    manager = JournalManager()
    while True:
        display_menu()
        choice = input("\nEnter your choice: ").strip()
        if choice == "1":
            entry_text = input("\nEnter your journal entry: ")
            manager.add_entry(entry_text)
        elif choice == "2":
            manager.view_entries()
        elif choice == "3":
            keyword = input("\nEnter a keyword or date to search: ")
            manager.search_entries(keyword)
        elif choice == "4":
            manager.delete_entries()
        elif choice == "5":
            print("Thank you for using Personal Journal Manager. Goodbye!")
            break
        else:
            print("Invalid option. Please select a valid option from the menu.")


if __name__ == "__main__":
    main()
# Out:
# Welcome to Personal Journal Manager!
# Please select an option:
#
# 1. Add a New Entry
# 2. View All Entries
# 3. Search for an Entry
# 4. Delete All Entries
# 5. Exit
# Enter your choice:  1
#
# Enter your journal entry:  Today was productive day. I learned about file handling in python.
# Entry added successfully!
#
# Welcome to Personal Journal Manager!
# Please select an option:
#
# 1. Add a New Entry
# 2. View All Entries
# 3. Search for an Entry
# 4. Delete All Entries
# 5. Exit
# Enter your choice:  2
# Your Journal Entries:
# ------------------------------
# [2026-07-13 21:35:01]
# Today was productive day. I learned about file handling in python.
#
# Welcome to Personal Journal Manager!
# Please select an option:
#
# 1. Add a New Entry
# 2. View All Entries
# 3. Search for an Entry
# 4. Delete All Entries
# 5. Exit
# Enter your choice:  3
#
# Enter a keyword or date to search:  productive
# Matching Entries:
# ------------------------------
# [2026-07-13 21:35:01]
# Today was productive day. I learned about file handling in python.
#
# Welcome to Personal Journal Manager!
# Please select an option:
#
# 1. Add a New Entry
# 2. View All Entries
# 3. Search for an Entry
# 4. Delete All Entries
# 5. Exit
# Enter your choice:  4
# Are you sure you want to delete all entries? (yes/no):  yes
# All journal entries have been deleted.
#
# Welcome to Personal Journal Manager!
# Please select an option:
#
# 1. Add a New Entry
# 2. View All Entries
# 3. Search for an Entry
# 4. Delete All Entries
# 5. Exit
# Enter your choice:  2
# No journal entries found. Start by adding a new entry!
#
# Welcome to Personal Journal Manager!
# Please select an option:
#
# 1. Add a New Entry
# 2. View All Entries
# 3. Search for an Entry
# 4. Delete All Entries
# 5. Exit
